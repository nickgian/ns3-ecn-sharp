# %%
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import pandas as pd
import numpy as np
from parseXml import *
from parseFlows import *
from plotInfo import *

# %%
# 3 paths experiment
import os 

directory = "/Users/gian/Documents/Madison/simulations/threePaths"
os.chdir(directory)
sim3 = []
for filename in os.listdir(directory):
    if filename.endswith(".flow"):
        sim3.append(parseSimulationFiles(filename.split('.')[0]))

    #sim37.sort(key=worstSenderAvgFct)

# %%
plotSimulationRange(sim3[0],(0,100))
# Out:
# Flowlet gap = 100, Flow size = 400000, Bulk attacker with offTime = 0, onTime = 1000, startTime: 0, flows: 1, rate: 0, attacker flow size= 0, Udp, buffer=b200
# Average Flows Cab Distance: 0.18604651162790697
# Average Flows Chebysev Distance: 0.09302325581395349
# Sender Avg FCT: 0.0058
# Sender Above Median Avg FCT: 0.2623
# Sender Below Median Avg FCT: 0.0012
# Sender Median FCT: 0.0041
# Sender Variance FCT: 0.1588
# Avg FCT: 0.0687
# Large Flows Avg FCT: 0.0024
# Small Flows Avg FCT: -1.0000
# Attacker Avg FCT: 1.2658
