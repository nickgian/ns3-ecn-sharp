# %% [markdown]
# # Testing stability of LetFlow after an attack, i.e. how long it takes to find a better state if ever.

# %%
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import pandas as pd
import numpy as np
from parseXml import *
from parseFlows import *
from plotInfo import *

# %%
import os 

directory = "/Users/gian/Documents/Madison/simulations/simLetflowBalance/4paths"
os.chdir(directory)
sim = []
for filename in os.listdir(directory):
    if filename.endswith(".flow"):
        sim.append(parseSimulationFiles(filename.split('.flow')[0]))

# %%
df = buildPanda((0,200),sim)
details = sim[0][2]
df = df.sort_values('LoadBalanceAvg', ascending=False)
show(df, "Fast path: " + str(details.get('FastCap')) + "Gbps, Slow path: " +  str(details.get('SlowCap')) + "Gbps, 20 flows + 1 attacker flow, yellow: 10%, red:20%, green: less than baseline")
# Out:
# <style  type="text/css" >
# ...

# %%
df = buildPanda((0,500),sim)
df = df.sort_values('LoadBalanceAvg', ascending=False)

show(df, "Fast path: " + str(details.get('FastCap')) + "Gbps, Slow path: " +  str(details.get('SlowCap')) + "Gbps, 20 flows + 1 attacker flow, yellow: 10%, red:20%, green: less than baseline")
# Out:
# <style  type="text/css" >
# ...

# %%
df = buildPanda((0,700),sim)
df = df.sort_values('LoadBalanceAvg', ascending=False)

show(df, "Fast path: " + str(details.get('FastCap')) + "Gbps, Slow path: " +  str(details.get('SlowCap')) + "Gbps, 20 flows + 1 attacker flow, yellow: 10%, red:20%, green: less than baseline")
# Out:
# <style  type="text/css" >
# ...

# %%
df = buildPanda((0,1000),sim)
df = df.sort_values('LoadBalanceAvg', ascending=False)

show(df, "Fast path: " + str(details.get('FastCap')) + "Gbps, Slow path: " +  str(details.get('SlowCap')) + "Gbps, 20 flows + 1 attacker flow, yellow: 10%, red:20%, green: less than baseline")
# Out:
# <style  type="text/css" >
# ...

# %%
df = buildPanda((0,2600),sim)
df = df.sort_values('LoadBalanceAvg', ascending=False)

show(df, "Fast path: " + str(details.get('FastCap')) + "Gbps, Slow path: " +  str(details.get('SlowCap')) + "Gbps, 20 flows + 1 attacker flow, yellow: 10%, red:20%, green: less than baseline")
# Out:
# <style  type="text/css" >
# ...
