# %% [markdown]
# # Letflow on conga-large-sim, for various traffic loads.

# %%
# %matplotlib inline
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import pandas as pd
import numpy as np
from parseXml import *
from parseFlows import *
from plotInfo import *

# %%
import os 

directory = "/Users/gian/Documents/Madison/simulations/simCongaLetFlow"
os.chdir(directory)
sim = []
for filename in os.listdir(directory):
    if filename.endswith(".xml"):
        sim.append(parseCongaSimulationFiles(filename))

# %%
df = buildCongaPanda(sim)
# details = sim[0][2]
df = df.sort_values('AvgFct', ascending=False)
# df = df[(df.rate.isin(['0','2000'])) & (~df.onTime.isin(['100']))]
#df = df[(df.AttackerFlows.isin(['2'])) | (df.offTime.isin(['0']))]
#df = df[(df.offTime.isin(['0','200']))]

# %%
df2 = df[(df.load == '0.2')]
showConga(df2, "4x4 spines/leafs, 8 servers on each leaf, yellow: 10%, red:20%, green: less than baseline, simulation time:2.5s, flow launch end time:2.15s")
# Out:
# <style  type="text/css" >
# ...

# %%
df5 = df[(df.load == '0.5')]
showConga(df5, "4x4 spines/leafs, 8 servers on each leaf, yellow: 10%, red:20%, green: less than baseline simulation time:2.5s, flow launch end time:2.15s")
# Out:
# <style  type="text/css" >
# #T_fe71df80_341d_11eb_8859_367dda732f87row1_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row7_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row10_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row11_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row13_col8,#T_fe71df80_341d_11eb_8859_367dda732f87row16_col8,#T_fe71df80_341d_11eb_8859_367dda732f87row19_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row28_col7,#T_fe71df80_341d_11eb_8859_367dda732f87row29_col8,#T_fe71df80_341d_11eb_8859_367dda732f87row38_col8,#T_fe71df80_341d_11eb_8859_367dda732f87row54_col8,#T_fe71df80_341d_11eb_8859_367dda732f87row60_col8{
#             background-color:  #FAE4A1;
# ...

# %%
df7 = df[(df.load == '0.7')]
showConga(df7, "4x4 spines/leafs, 8 servers on each leaf, yellow: 10%, red:20%, green: less than baseline simulation time:2.5s, flow launch end time:2.15s")
# Out:
# <style  type="text/css" >
# #T_fe84ab9c_341d_11eb_8859_367dda732f87row0_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row1_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row2_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row3_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row4_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row5_col7,#T_fe84ab9c_341d_11eb_8859_367dda732f87row10_col8,#T_fe84ab9c_341d_11eb_8859_367dda732f87row27_col8,#T_fe84ab9c_341d_11eb_8859_367dda732f87row35_col7{
#             background-color:  #FAE4A1;
# ...

# %%
df9 = df[(df.load == '0.9')]
showConga(df9, "4x4 spines/leafs, 8 servers on each leaf, yellow: 10%, red:20%, green: less than baseline simulation time:2.5s, flow launch end time:2.15s")
# Out:
# <style  type="text/css" >
# #T_fe9954f2_341d_11eb_8859_367dda732f87row0_col7{
#             background-color:  #E6584F;
# ...
